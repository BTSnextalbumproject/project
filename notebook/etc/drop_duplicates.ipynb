# %% [markdown]
# ## 구글 드라이브 마운트

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/project')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('billboardTop100.csv', encoding = 'utf-8')
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbf in position 2: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-82728f559fee> in <cell line: 1>()
# ----> 1 data = pd.read_csv('billboardTop100.csv', encoding = 'utf-8')
#       2 data
#
# ...

# %%
data.groupby(['Title', 'Artist']).Rank.count().reset_index().drop(columns = 'Rank').to_csv('billboardTop100_drop_duplicates.csv')
# Out:
#                                                   Title  \
# 0                                            '98 Braves
# 1                                        'Til You Can't
# 2                                  'Tis The Damn Season
# 3     (There's No Place Like) Home For The Holidays ...
# 4                                               07월 24일
# ...                                                 ...
# 3205                                 pride.is.the.devil
# 3206                                 punchin'.the.clock
# 3207                                     the.climb.back
# 3208                                    transparentsoul
# 3209                                 whoa (mind in awe)
#
#                                                 Artist
# 0                                        Morgan Wallen
# 1                                         Cody Johnson
# 2                                         Taylor Swift
# 3     Perry Como With Mitchell Ayers And His Orchestra
# ...
