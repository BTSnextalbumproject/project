# %% [markdown]
# * neg: 부정 점수
# * neu: 중립 점수
# * pos: 긍정 점수
# * compound: 종합 점수(-1에서 1 사이의 값, 감정의 전반적인 강도)
# <br>
# 종합 점수가 0.05 이상이면 긍정, -0.05 이하이면 부정

# %% [markdown]
# ## 구글 드라이브 마운트

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/project')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 라이브러리

# %%
import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
lyrics = pd.read_csv('data/filled_data.csv')
lyrics
# Out:
#        Year  Month  Week  Rank              Title  \
# 0      2014      1     2     1        The Monster
# 1      2014      1     2     2             Timber
# 2      2014      1     2     3     Counting Stars
# 3      2014      1     2     4             Royals
# 4      2014      1     2     5      Say Something
# ...     ...    ...   ...   ...                ...
# 52295  2023     12     5    96  Winter Wonderland
# 52296  2023     12     5    97  Run For The Hills
# 52297  2023     12     5    98           Que Onda
# 52298  2023     12     5    99       Great Gatsby
# 52299  2023     12     5   100   One Of The Girls
#
#                                        Artist  \
# 0                    Eminem Featuring Rihanna
# 1                     Pitbull Featuring Ke$ha
# 2                                 OneRepublic
# 3                                       Lorde
# 4      A Great Big World & Christina Aguilera
# ...                                       ...
# ...

# %%
test1 = lyrics.iloc[31].Lyrics

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

# for text in test1:
#     scores = sia.polarity_scores(text)
#     print(f"Text: {text}")
#     print(f"Scores: {scores}")

scores = sia.polarity_scores(test1)
print(f"Scores: {scores}")
# Out:
# Scores: {'neg': 0.1, 'neu': 0.788, 'pos': 0.112, 'compound': 0.3506}
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
